# %% [markdown]
# # Data Exploration
#
# Explore the fake and real news datasets before training the model.

# %%
from pathlib import Path
import pandas as pd

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
DATA_DIR = PROJECT_ROOT / "data" / "raw"

fake_path = DATA_DIR / "Fake.csv"
true_path = DATA_DIR / "True.csv"

fake = pd.read_csv(fake_path)
true = pd.read_csv(true_path)

fake["label"] = 0
true["label"] = 1

df = pd.concat([fake, true], ignore_index=True)
df.head()

# %% [markdown]
# ## Dataset Shape

# %%
print("Fake shape:", fake.shape)
print("True shape:", true.shape)
print("Combined shape:", df.shape)

# %% [markdown]
# ## Columns

# %%
df.columns.tolist()

# %% [markdown]
# ## Label Distribution
#
# - `0` = FAKE
# - `1` = REAL

# %%
df["label"].value_counts().sort_index()

# %% [markdown]
# ## Missing Values

# %%
df.isna().sum()

# %% [markdown]
# ## Text Length

# %%
df["text_length"] = df["text"].fillna("").astype(str).str.split().str.len()
df.groupby("label")["text_length"].describe()

# %% [markdown]
# ## Sample Fake News

# %%
fake[["title", "text", "subject", "date"]].head(3)

# %% [markdown]
# ## Sample Real News

# %%
true[["title", "text", "subject", "date"]].head(3)

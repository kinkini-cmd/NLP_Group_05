# %% [markdown]
# # Model Training
#
# Train, evaluate, save, and test the fake news detection models.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(PROJECT_ROOT))

PROJECT_ROOT

# %% [markdown]
# ## 1. Preprocess Data

# %%
from src.preprocess import save_data

save_data()

# %% [markdown]
# ## 2. Train Models

# %%
from src.train_svm import train

train()

# %% [markdown]
# ## 3. Test Saved Predictor

# %%
from src.predict import predict_news_details

samples = [
    "Government Launches New Digital Services Platform",
    "The government launched a new digital services platform on Monday to improve access to public services.",
    "Breaking shocking secret exposed you will not believe what happened next",
]

for text in samples:
    result = predict_news_details(text)
    print(f"Text: {text}")
    print(f"Prediction: {result['label']}")
    print(f"Fake: {result['fake_percentage']}%")
    print(f"Real: {result['real_percentage']}%")
    print()

# %% [markdown]
# ## 4. Predict Your Own News

# %%
news_text = input("Enter news text: ")
result = predict_news_details(news_text)

print("Prediction:", result["label"])
print("Fake:", f"{result['fake_percentage']}%")
print("Real:", f"{result['real_percentage']}%")

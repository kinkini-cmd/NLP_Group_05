# %%
import sys
import os

sys.path.append(
    os.path.abspath("..")
)

from preprocessing.preprocess import preprocess_text
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/kinkini/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/kinkini/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /home/kinkini/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import pandas as pd

from preprocessing.preprocess import preprocess_text

# %%
fake = pd.read_csv("/home/kinkini/Desktop/multilingual-fake-news-detector/datasets/raw/Fake.csv")
real = pd.read_csv("/home/kinkini/Desktop/multilingual-fake-news-detector/datasets/raw/True.csv")

fake["label"] = 0
real["label"] = 1

df = pd.concat([fake, real])

# %%
df["content"] = (
    df["title"].fillna("")
    + " "
    + df["text"].fillna("")
)

# %%
df["clean_text"] = df["content"].apply(
    preprocess_text
)

# %%
df[
    ["content","clean_text"]
].head()
# Out:
#                                              content  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                           clean_text
# 0  donald trump sends embarrassing new year’s eve...
# 1  drunk bragging trump staffer started russian c...
# 2  sheriff david clarke becomes internet joke thr...
# 3  trump obsessed even obama’s name coded website...
# 4  pope francis called donald trump christmas spe...

# %%
import os

print(os.getcwd())
# Out:
# /home/kinkini/Desktop/multilingual-fake-news-detector/notebooks

# %%
import os

print(os.listdir())
# Out:
# ['04_xlmr_training.ipynb', '01_data_exploration.ipynb', '02_preprocessing.ipynb', '03_svm_training.ipynb', '05_model_comparison.ipynb']

# %%
print(os.listdir(".."))
# Out:
# ['app', 'models', 'language_detection', 'README.md', 'feature_extraction', 'data', 'Dockerfile', 'notebooks', '.gitignore', 'test_multiple.py', 'requirements.txt', 'tests', 'scraper', 'venv312', 'test_model.py', 'venv', 'translator', 'docker-compose.yml', 'datasets', 'preprocessing', 'run.py']

# %%
import os

os.makedirs("../data", exist_ok=True)

# %%
df.to_csv(
    "../data/processed_news.csv",
    index=False
)

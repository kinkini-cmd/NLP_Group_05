# %%
# SVM results (from training)
svm_results = {
    "Model": "SVM",
    "Accuracy": 0.9949,
    "Precision": 0.9950,
    "Recall": 0.9948,
    "F1": 0.9949,
    "Training_Time_Min": 2,
    "Inference": "Fast"
}

svm_results
# Out:
# {'Model': 'SVM',
#  'Accuracy': 0.9949,
#  'Precision': 0.995,
#  'Recall': 0.9948,
#  'F1': 0.9949,
#  'Training_Time_Min': 2,
#  'Inference': 'Fast'}

# %%
# XLM-R / MiniLM results (example values)
xlmr_results = {
    "Model": "XLM-R",
    "Accuracy": 0.9780,
    "Precision": 0.9770,
    "Recall": 0.9790,
    "F1": 0.9780,
    "Training_Time_Min": 25,
    "Inference": "Medium"
}

xlmr_results
# Out:
# {'Model': 'XLM-R',
#  'Accuracy': 0.978,
#  'Precision': 0.977,
#  'Recall': 0.979,
#  'F1': 0.978,
#  'Training_Time_Min': 25,
#  'Inference': 'Medium'}

# %%
import pandas as pd

comparison_df = pd.DataFrame([
    svm_results,
    xlmr_results
])

comparison_df
# Out:
#    Model  Accuracy  Precision  Recall      F1  Training_Time_Min Inference
# 0    SVM    0.9949      0.995  0.9948  0.9949                  2      Fast
# 1  XLM-R    0.9780      0.977  0.9790  0.9780                 25    Medium

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))

plt.bar(
    comparison_df["Model"],
    comparison_df["Accuracy"]
)

plt.ylabel("Accuracy")
plt.title("Model Accuracy Comparison")
plt.ylim(0.9, 1.0)

plt.show()

# %%
plt.figure(figsize=(6,4))

plt.bar(
    comparison_df["Model"],
    comparison_df["Training_Time_Min"]
)

plt.ylabel("Training Time (minutes)")
plt.title("Training Time Comparison")

plt.show()

# %%
import os

os.makedirs("results", exist_ok=True)

# %%
comparison_df.to_csv(
    "results/model_comparison.csv",
    index=False
)

# %%
comparison_df.to_csv(
    "results/model_comparison.csv",
    index=False
)

# %%
comparison_df.to_csv(
    "model_comparison.csv",
    index=False
)

# %%
import os
print(os.getcwd())
# Out:
# /home/kinkini/Desktop/multilingual-fake-news-detector/notebooks
